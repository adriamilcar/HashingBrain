# %%
# %matplotlib inline
from utils import *
from plotting import *
from models import *

# %% [markdown]
# ## Load data and model

# %%
tasks = ['openArena', 'doubleTmaze', 'cylinder', 'permanence', 'thorndike']

# %%
task = tasks[0]
load_pose = True
dataset, pose = load_dataset('datasets/'+task, file_format='.npy', load_pose=load_pose)
train_loader = create_dataloader(dataset, batch_size=256, reshuffle_after_epoch=True)

if load_pose:
    position = pose[:,:2]
    orientation = pose[:,2]

# %%
model = Conv_AE(n_hidden=1000).to('cuda')
#model.load_state_dict(torch.load('saved_models/{}_sparse-AE_1000hidden.pth'.format(task)))
model.load_state_dict(torch.load('saved_models/AE_ortho.pth'.format(task)))

# %%
embeddings = get_latent_vectors(dataset, model)
embeddings[embeddings<1e-5] = 0
embeddings.shape

# %% [markdown]
# ## Activation clamping

# %%
clamping_value = np.mean(np.max(clean_embeddings(embeddings), axis=0))
clamping_value

# %%
features = extract_feature_images(model, clean_embeddings(embeddings), clamping_value=0.217)

# %%
plt.figure(figsize=(16,10))
for i in range(50):
    plt.subplot(5, 10, i+1)
    plt.imshow(features[i], interpolation='bilinear')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Maximum activation samples

# %%
embeddings_active = np.where(embeddings<0.8*embeddings.max(axis=0), 0, 1)
embeddings_active_specific = embeddings_active[:, np.mean(embeddings_active, axis=0)<1].T
embeddings_active_specific.shape

indxs_embeddings_active_specific = []
for embeddings_ in embeddings_active_specific:
    indxs_embeddings_active_specific.append( np.nonzero(embeddings_) )

# %%
plt.figure(figsize=(16,10))
indx=5
for i in range(50):
    plt.subplot(5, 10, i+1)
    if i < dataset[indxs_embeddings_active_specific[indx]].shape[0]:
        plt.imshow(dataset[indxs_embeddings_active_specific[indx]][i], interpolation='bilinear')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4,4))

#plt.imshow(np.sum(all_ratemaps[:-1], axis=0), cmap='hot', origin='lower')
x = position[indxs_embeddings_active_specific[indx],0]
y = position[indxs_embeddings_active_specific[indx],1]
plt.scatter(x, y, color='black', marker='x', s=80)
#plt.axis('off')

plt.tight_layout()
#plt.axis('off')
plt.ylim(0, 40)
plt.xlim(0, 40)
plt.show()

# %% [markdown]
# ## Activation maximization (gradient ascent in image space)

# %%
opt_act_imgs = find_max_activation_images(model, embeddings, dataset, img_shape=[3, 84, 84], 
                                          init='max_avg', num_epochs=2000, lr=1e-1)
# Out:
# ...
# Unit 375/687, Loss: -6.1107: 100%|█████████████████████████████████████████████████████████| 2000/2000 [00:20<00:00, 99.40it/s]
# ...
# ...
# Unit 687/687, Loss: -6.8973: 100%|████████████████████████████████████████████████████████| 2000/2000 [00:19<00:00, 105.13it/s]

# %%
plt.figure(figsize=(16,10))
for i in range(50):
    plt.subplot(5, 10, i+1)
    plt.imshow(opt_act_imgs[i], interpolation='bilinear')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[141], line 4
#       2 for i in range(50):
#       3     plt.subplot(5, 10, i+1)
# ----> 4     plt.imshow(opt_act_imgs[i], interpolation='bilinear')
#       5     plt.axis('off')
#       6 plt.tight_layout()
#
# NameError: name 'opt_act_imgs' is not defined

# %% [markdown]
# ## Tiling of the image space

# %% [markdown]
# #### Encode images with CLIP, VGG16, or InceptionV3

# %%
features = encode_images(dataset, network='CLIP')  # 'CLIP', 'VGG', or 'Inception'
features.shape
# Out:
# (20000, 512)

# %% [markdown]
# #### Reduce dimensionality with UMAP, t-SNE, or MDS

# %%
images_2d = reduce_dimensionality(features, method='UMAP')  # 'UMAP', 'TSNE', or 'MDS'
images_2d.shape
# Out:
# (20000, 2)

# %%
#np.save('results/2d_imageSpace_CLIP-UMAP.npy', images_2d)

# %%
#images_2d = np.load('results/2d_imageSpace_InceptionV3-MDS.npy')
#images_2d = np.load('results/2d_imageSpace_VGG16-tSNE.npy')
#images_2d = np.load('results/2d_imageSpace_CLIP-UMAP.npy')

# %% [markdown]
# #### Hulls based on clustering in 2D space

# %%
max_act_thres = 0.8
overlap, hulls = build_hulls(embeddings, images_2d, max_act_thres=max_act_thres)
overlap

# %%
from matplotlib.patches import Polygon as MplPolygon
from matplotlib.collections import PatchCollection

fig, ax = plt.subplots()

# Create a patch collection with the polygons
patches = []
for poly in hull_polygons:
    polygon = MplPolygon(list(poly.exterior.coords), True)
    patches.append(polygon)

p = PatchCollection(patches, cmap=plt.cm.jet, alpha=0.4)

# Define colors for the polygons
colors = 100 * np.random.rand(len(patches))
p.set_array(np.array(colors))

ax.add_collection(p)

# Set limits and labels
ax.set_xlim(min([point[0] for poly in hull_polygons for point in poly.exterior.coords]),
            max([point[0] for poly in hull_polygons for point in poly.exterior.coords]))
ax.set_ylim(min([point[1] for poly in hull_polygons for point in poly.exterior.coords]),
            max([point[1] for poly in hull_polygons for point in poly.exterior.coords]))
ax.set_xlabel('Dimension 1')
ax.set_ylabel('Dimension 2')
plt.title(f'Overlap: {average_overlap_metric:.3f}', fontsize=18)

#plt.colorbar(p, ax=ax)

plt.axis('off')

plt.tight_layout()

plt.savefig('plots/overlap_imageSpace_CLIP-UMAP-DBSCAN_ortho.png', dpi=600)

plt.show()

# %% [markdown]
# #### Visualizing clusters in dense cloud

# %%
unit_indx = 127

plt.scatter(images_2d[:,0], images_2d[:,1], s=.1)
points = images_2d[indxs_embeddings_active_specific[unit_indx][0]]
plt.scatter(points[:,0], points[:,1], s=10)

clustering = DBSCAN(eps=1., min_samples=4).fit(points)
labels = clustering.labels_

for k in set(labels):
    if k != -1:  # Ignore noise points
        class_member_mask = (labels == k)
        cluster_points = points[class_member_mask]

        if len(cluster_points) >= 3:
            hull = ConvexHull(cluster_points)
            polygon = Polygon(cluster_points[hull.vertices])
            hull_polygons.append(polygon)

            # Plot the convex hull
            x, y = polygon.exterior.xy
            plt.fill(x, y, alpha=0.5)

plt.show()

# %% [markdown]
# ### Overlap across max activity threshold values

# %%
model_ortho = Conv_AE(n_hidden=1000).to('cuda')
model_ortho.load_state_dict(torch.load('saved_models/AE_ortho.pth'.format(task)))
embeddings_ortho = get_latent_vectors(dataset, model_ortho)
embeddings_ortho[embeddings_ortho<1e-5] = 0

model_nonortho = Conv_AE(n_hidden=1000).to('cuda')
model_nonortho.load_state_dict(torch.load('saved_models/AE_non-ortho.pth'.format(task)))
embeddings_nonortho = get_latent_vectors(dataset, model_nonortho)
embeddings_nonortho[embeddings_nonortho<1e-5] = 0

# %%
all_embeddings = [embeddings_ortho, embeddings_nonortho]

# %%
all_overlaps = []
for embeddings_ in all_embeddings:
    max_act_thres_range = np.linspace(0.5, 0.9, 20)
    overlaps = []
    for thres in max_act_thres_range:
        print(thres)
        
        overlap, hulls = build_hulls(embeddings, images_2d, max_act_thres=thres)
        overlaps.append(overlap)
    
    all_overlaps.append(overlaps)
# Out:
# 0.5
# 0.5210526315789473
# 0.5421052631578948
# 0.5631578947368421
# 0.5842105263157895
# 0.6052631578947368
# 0.6263157894736842
# 0.6473684210526316
# 0.6684210526315789
# 0.6894736842105263
# 0.7105263157894737
# 0.7315789473684211
# 0.7526315789473684
# 0.7736842105263158
# 0.7947368421052632
# 0.8157894736842105
# 0.8368421052631578
# 0.8578947368421053
# 0.8789473684210527
# 0.9
# 0.5
# 0.5210526315789473
# 0.5421052631578948
# 0.5631578947368421
# 0.5842105263157895
# 0.6052631578947368
# 0.6263157894736842
# 0.6473684210526316
# 0.6684210526315789
# 0.6894736842105263
# 0.7105263157894737
# 0.7315789473684211
# 0.7526315789473684
# 0.7736842105263158
# 0.7947368421052632
# 0.8157894736842105
# 0.8368421052631578
# 0.8578947368421053
# 0.8789473684210527
# 0.9

# %%
plt.figure(figsize=(6,5))

colors = ['blue', 'orange']
labels = ['ortho.', 'non-ortho.']
for i, overlaps in enumerate(all_overlaps):
    plt.plot(max_act_thres_range, overlaps, c=colors[i], linewidth=2, label=labels[i])

plt.xticks(np.linspace(0.5, 0.9, 5).round(2), np.linspace(0.5, 0.9, 5).round(2), fontsize=16)
plt.yticks(fontsize=16)

plt.xlabel('Threshold (% of max. act.)', fontsize=18)
plt.ylabel('Avg. hull overlap \n(% of max. overlap)', fontsize=18)

plt.legend(fontsize=14, frameon=False)

sb.despine()
plt.tight_layout()

#plt.savefig('plots/overlap_across_thresholds.png', dpi=600)

plt.show()
