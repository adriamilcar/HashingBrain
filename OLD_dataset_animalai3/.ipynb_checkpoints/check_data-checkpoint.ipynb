# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(10):
    plt.imshow(np.load('{:05d}'.format(i+6000)+'.npy'))
    plt.show()

# %%
pose = np.vstack((np.load('pose.npy'), np.load('pose_2.npy')))

# %%
np.save('pose_all.npy', pose)

# %%
np.load('pose_all.npy').shape
# Out:
# (10000, 3)

# %%
pose = np.load('pose.npy')

# %%
plt.scatter(pose[:,0], pose[:,1], s=.01)
plt.xlim(0,40)
plt.ylim(0,40)
# Out:
# (0.0, 40.0)

# %%
np.count_nonzero(pose[:,:2]==[15,30])
# Out:
# 696
