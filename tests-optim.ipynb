# %%
# %matplotlib inline
from utils import *
from plotting import *
from models import *
from sklearn.decomposition import PCA

# %%
dataset, pose = load_dataset('datasets/openArena', file_format='.npy', load_pose=True, pose_filename='pose.npy')
train_loader = create_dataloader(dataset, batch_size=256, reshuffle_after_epoch=True)

# %%
position = pose[:,:2]
orientation = pose[:,2]

# %%
model = Conv_AE(n_hidden=1000).to('cuda')

# %%
history, _, _, _ = train_autoencoder(model, train_loader, opt=optim.RMSprop, num_epochs=20000, learning_rate=1e-5, alpha=2e3)
# Out:
# ...
# Epoch 375/10000, Loss: 0.0086: 100%|███████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 36.83it/s]
# ...
# ...
# Epoch 3187/10000, Loss: 0.0007:  18%|██████████▎                                               | 14/79 [00:00<00:02, 28.69it/s]
#
# KeyboardInterrupt

# %%
embeddings = get_latent_vectors(dataset, model)

# %%
all_ratemaps = ratemaps(embeddings, position, n_bins=50, filter_width=3, occupancy_map=[], n_bins_padding=5)

# %%
np.count_nonzero( np.any(all_ratemaps, axis=(1,2)) )

# %%
plot_ratemaps(all_ratemaps[0:100])

# %%
plot_ratemaps(all_ratemaps[100:200])

# %%
plt.imshow(np.dot(embeddings.T, embeddings))
plt.show()
